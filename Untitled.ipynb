# %%
from pdf2docx import Converter

pdf_file = 'C:/Users/Dell/PycharmProjects/OpencvTest/Practice area/Elite-i20_Hatchback_brochure.pdf'

cv = Converter(pdf_file)
tables = cv.extract_tables(start=1, end=14)
cv.close()

for table in tables:
    print(table)
# Out:
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansHeadMedium" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansHeadMedium" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansHeadMedium" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansHeadMedium" with "Times New Roman" due to lack of data.
# ...

# %%
from pdf2docx import Converter

pdf_file = 'C:/Users/Dell/PycharmProjects/OpencvTest/Practice area/Elite-i20_Hatchback_brochure.pdf'
docx_file = 'C:/Users/Dell/PycharmProjects/OpencvTest/Practice area/Elite-i20_Hatchback_brochure.docx'

# convert pdf to docx
cv = Converter(pdf_file)
# cv.convert(docx_file)      # all pages by default
cv.convert(docx_file, start=13, end=14)
cv.close()
# Out:
# [INFO] Start to convert C:/Users/Dell/PycharmProjects/OpencvTest/Practice area/Elite-i20_Hatchback_brochure.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansHeadMedium" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansHeadMedium" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansHeadMedium" with "Times New Roman" due to lack of data.
# [WARNING] Replace font "HyundaiSansText" with "Times New Roman" due to lack of data.
# ...
